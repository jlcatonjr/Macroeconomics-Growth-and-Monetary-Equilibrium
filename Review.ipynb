# %% [markdown]
# # Review
#
# ## Chapter 1
#
# 1. Economic theory is the study of action in terms of ______ and ______.
#
# >a. demand and supply
# >
# >b. rationing and value
# >
# >**c. means and ends**
# >
# >d. supply and value
#
# 2. Suppose that, before Friday arrives on the island, Robinson Crusoe catches 10 fish in one day. If Robinson Crusoe can only produce one type of good per day, what is his opportunity cost for catching 10 fish?
#
#
# | |Production Possibilities Frontier||
# | --- | --- | --- |
# | | **RC** | **F**|
# | **Clothing** | $20$ | $20$ |
# | **Fish** | $10$ | $30$ |
#
#
# >a. 1 piece of clothing
# >
# >**b. 2 pieces of clothing**
# >
# >c. 10 pieces of clothing
# >
# >d. 20 pieces of clothing
#
#
#
# 3. Governance is itself a technology?
#
# >a. True
# >
# >b. True.
#
# ## Chapter 2
#
# 1. Suppose that, before Friday arrives on the island, Robinson Crusoe catches 10 fish in one day. If Robinson Crusoe can only produce one type of good per day, what is his opportunity cost?
#
# >a. True
# >
# >b. False
#
# #### Recall the example of Clara in the section, _Opportunity Cost and Money Accounting_
#
# 2. Suppose that Clara is a web designer who operates as a sole proprietor. Every month she pays 1500 dollars for an office, 100 dollars for equipment and software, and 100 dollars on advertising. Each month, she earns 4000 dollars in revenue. What is Clara's accounting profit each month? (do not include units of dollars / $)
#
# 3. Suppose that Clara is a web designer who operates as a sole proprietor. Every month she pays 1500 dollars for an office, 100 dollars for equipment and software, and 100 dollars on advertising. Each month, she earns 4000 dollars in revenue. What is Clara's accounting profit each month?
#
# 4. Suppose that that the market demand function for burgers is $p=-\frac{Q}{4800} + 0.75$. If the price of a burger is 0.50, how many burgers will consumers be willing to purchase.
#
# 5. Suppose that demand was originally represented by the equation, P = -\frac{Q}{4800} + .75. After a shift in demand, the new curve is P = -\frac{Q}{4800} + 0.50. Did demand increase or decrease?
#
# 6. Mark the point representing the new equilibrium price and quantity that occurs after a shift in the supply curve.
#
# >a.<img src="https://github.com/jlcatonjr/Macroeconomics-Growth-and-Monetary-Equilibrium/blob/main/Chapter%202/Figure%2013.png?raw=true" alt="Demand Decreases" title="Demand Decreases"/>
# >
# >b. <img src="https://github.com/jlcatonjr/Macroeconomics-Growth-and-Monetary-Equilibrium/blob/main/Chapter%202/Figure%2012.png?raw=true" alt="Demand Increases" title="Demand Increases"/>
# >
# >c. <img src="https://github.com/jlcatonjr/Macroeconomics-Growth-and-Monetary-Equilibrium/blob/main/Chapter%202/Figure%2015.png?raw=true" alt="Supply Decreases" title="Supply Decreases"/>
# >
# >d. <img src="https://github.com/jlcatonjr/Macroeconomics-Growth-and-Monetary-Equilibrium/blob/main/Chapter%202/Figure%2014.png?raw=true" alt="Supply Increases" title="Supply Increases"/>
#
# 7. Suppose that consumers experience an increase in income and burgers are a normal good. Suppose also that the supply curve for burgers is upward sloping. Which of the following are true?
#
# >a. The supply of burgers will increase
# >
# >b. The demand for burgers will increase
# >
# >c. The quantity of burgers supplied will increase
# >
# >d. The price of burgers will increase
#
# 8. Suppose that the equation for the supply of hamburgers is, $P = \frac{Q}{4800} - 0.25$. The equation representing the demand for hamburgers is $P = -\frac{Q}{4800} + 0.75$. If the price of burgers is set by law to 0.50, what is the difference between the quantity supplied and quantity demanded ($Q_s - Q_d$).
#
# ## Chapter 3
#
#
# 1. Define each variable from the Equation of Exchange. Use words and reorganize the equation of exchange to define the variable. $M$ is completed as an example
#
# >a. $M$: the quantity of money circulating in the economy; $M=\frac{Py}{V}$
# >
# >b. V
# >
# >c. P
# >
# >d. y
#
# 2. Suppose that in the United States in 2015, the value of consumption was 10 trillion dollars, the value of investment was 5 trillion dollars, the value of government spending was 2 trillion dollars, the value of exports was 4 trillion dollars, and the value of imports was 5 trillion dollars. What is nominal GDP (in trillions of dollars)?
#
# 3. Define each of the following variables from the expenditure approaach to defining nominal income:
# >a. $C$
# >
# >b. $I$
# >
# >c. $G$
# >
# >d. $X$
# >
# >e. $M$
# >
# >g. $X - M$
#
# 4. Real GDP estimates income adjusted for
# >a. changes in velocity
# >
# >b. changs in the price level
# >
# >c. changes in nominal income
# >
# >d. changes in nominalism
#
# 5. Suppose that the quantity of money in circulation is 5 million dollars and nominal GDP is 45 million dollars. Calculate the velocity of money?
#
# 6. Suppose that the quantity of money increases by 10\%, the price level increases by 5\%, and real income increases by 3\%. What is true about the value of velocity?
#
#
# ## Chapter 4
#
#
# 1. The price level adjusts to promote monetary equilibrium in the short-run:
# a. False
# b. True
# c. Not enough information
#
# 2. The short-run refers to any instance where:
# a. the price level has reached its equilibrium value
# b. real income has reached its equilibrium value
# c. the price level and real income have not attained their equilibrium values
# d. none of the above
#
# #### Suppose that $y = k^{0.5}$ and that $k = 25$
# 3. What is the level of effective real income, $y$, generated from this level of effective capital?
#
# #### Suppose that the value of effective capital, $k$, in the current period is 16, the rate of depreciation, $\delta$, is 0.1, the return to capital, $\alpha$, is 0.5, and the rate of savings, $s$, is 0.2.
#
# 4. What will be the new value of effective capital. $k$ in the next period?
#
# #### Suppose that the value of effective capital, $k$, in the current period is 36, the rate of depreciation, $\delta$, is 0.1, the return to capital, $\alpha$, is 0.5, and the rate of savings, $s$, is 0.2.
# 5. What will be the new value of effective capital, $k$, in the next period?
#
# #### Suppose that the rate of depreciation, $\delta$, is 0.1, the return to capital, $\alpha$, is 0.5, and the rate of savings, $s$, is 0.2.
#
# 6. What is the steady state level of effective capital, $k$?
# 7. What is the steady state level of effective real income, $y$?
#
# #### Suppose that the rate of depreciation, $\delta$, is 0.1, the return to capital $\alpha$, is 0.5, the rate of savings, $s$, is 0.2, and the value of the technical efficiency of capital, $A$, is 2.
#
# 8. What is the steady state value of effective capital, $k$?
# 9. What is the real income, $y$?
#
# 10. In the steady state, the value of investment in capital each period:
# a. is greater than the value of capital depreciation
# b. is less than the value of capital depreciation
# c perfectly offsets the value of capital depreciation
#
# #### Recall that $MV \equiv PY$. Suppose that $M_0=1000$, $V_0=3$, $y_0=30$, and $P_0=100$
#
# 11. If $y_1$ represents an increase in real income to 60 units of real income, what will the new price level be if aggregate demand ($MV$) remains unchanged?
#
# ## Chapter 5
#
#
# 1. True or False?: Without money, it is possible to precisely evaluate an improvement in one's wealth that results from exchange.
#
# 2. List the attributes of a good that can efficiently be used as money.
#
# 3. The supply of real cash ablances measures:
#
# >a. the real quantity of money
# >
# >b. the value of money balances adjusted for inflation
# >
# >A and B
#
# 4. An increase in the supply of money tends to
#
# >a. increase the value of money
# >
# >b. decrease the value of money
# >
# >c. have no impact on the value of money
# >
# >d. not enough information
#
# 5. Changes in the demand for money:
#
# >a. are positively correlated with changes in the price of money
# >
# >b. are negatively correlated with the price of money
# >
# >c. tend not to impact the price of money
#
# 6. The state may attempt to monopolize money production because:
#
# >a. competitors could use devalued money in attempt to destabilize the ruling government
# >
# >b. the state may provide confidence in the quality of money by inclusion of the state seal
# >
# >c. monetary devaluation may serve as a source of revenue for the state (seignorage)
# >
# >d. all of the above
#
# ## Chapter 6
#
#
# 1. **Suppose that the money stock increases from 100 to 150 dollars and that the velocity of money is 10 throughout this time.**
#
# >a. Plot the change in money in a money supply and graph. Indicate the change in the price of money using $P_{M_0}$ to market the initial price of money and $P_{M_1}$ to mark the new price of money. Indicate the numeric value of money at the initial equilibrium and at the new equililbrium. Be sure to label your axes.
# >
# >b. What is the initial value of aggregate demand. What is the new value of aggregate demand after the supply of money has increased?
# >
# > c. Suppose that the value of real income is 20 dollars using the price level from the initial period to calculate. (Hint: $P_0$ = 1.00) What is the new price level, $P_1$, in period 1?
# >
# >d. In a graph of aggregate demand and aggregate supply, show the change in aggregate demand indicating the new equilibrium price level.
#
#
# 2. **Write the equation defining portfolio demand in terms of**:
#
# >a. the velocity of money.
# >
# >b. $M$, $P$, and $y$.
#
#
# 3. __Suppose the velocity of money is 10, the quantity of money is 1000, and the price level is 1.00.__
#
# >a. What is the value of portfolio demand for money.
# >
# >b. What is the equilibrium value of nominal income and real income?
# >
# > __Suppose that real income increases to a value of 12000.__
# >
# >c. What is the new equilibrium price level?
# >
# >d. What is the new equilibrium value of real income and nominal income.
#
# 4. An excess demand for money implies that:
#
# >a. prices need to fall on average for the economy to arrive at the new equilibrium combination of the price level and real income.
# >
# >b. there is an excess supply of non-money goods
# >
# >c. more money is demanded than can be satisfied at the current price level
# >
# >d. all of the above
#
# 5. Indicate the excess demand for money that exists after the supply of money has changed but before the price of money has increased.
#
# > <img src="https://github.com/jlcatonjr/Macroeconomics-Growth-and-Monetary-Equilibrium/blob/main/Chapter%206/Figure%2012.png?raw=true" alt="Decrease in Supply of Money: Excess Demand for Money"/>
#
# ## Chapter 7
#
# #### Suppose that $M_0 = 1000$, $V_0 = 3$, $P_0 = 50$, and $y_0 = 60$.
#
# 1. What will be the new value of nominal income if the money supply increases to 1500 dollars?
#
# 2. Does an increase in real income represents an increase in demand for money? Why or why not?
#
# 3. True or False?: An increase in real income is equivalent to an increase in portfolio demand for money?
#
# 4. Show using a graph of the money market and a graph of aggregate supply and demand, how an fall in aggregate demand driven by an increase in portfolio demand for money could be dampened by an increase in the quantity of money produced. (Hint: the supply of money is not perfectly inelastic in this case)
#
# 5. True or False?: Under the gold standard - where gold was used as money - if aggregate demand fell due to an increase in demand to hold money, eventually increased gold production would offset this fall in aggregate demand.
#
# ## Chapter 8
#
# 1. If investors expect that economic growth will increase:
#
# >a. they will be willing to borrow more money for the purpose of production
# >
# >b. they will be willing to borrow money at higher rates for the purpose of production.
# >
# >c. they will borrow less money than they had before they formed this expectation
# >
# >d. a and b
#
# 2. Suppose that you make a loan to a friend for 1000 dollars. He agrees to pay back 1210 dollars in two years. What is the interest rate? assume that interest is compounded annually.
#
# 3. If the nominal interest rate is 12% and teh inflation rate is 9%, what is the real interest rate?
#
# 4. As the quantity of credit in circulation increases:
#
# >a. the velocity of the monetary base decreases
# >
# >b. the velocity of the monetary base remains the same
# >
# >c. the velocity of the monetary base increases
# >
# >d. none of the above
#
# 5. Indicate which of the following is false. The money multplier:
#
# >a. reflects that banks create money without restraint
# >
# >b. indicates the magnitude by which the creation of credit enables an increase in total expenditures
# >
# >c. is positively correlated with changes in the velocity of the base
