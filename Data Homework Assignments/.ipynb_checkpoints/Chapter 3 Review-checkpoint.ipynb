# %%
import datetime
from datlib.FRED import *
#Import monetary base
# MV = Py
# Download: M, Py, y
#  M: Quantity of Base Money
#  Py: Nominal GDP
#  y: Real GDP

# Calculate: V, P
# V: Velocity
# P: Price Level (GDP Deflator)

data_codes  = {"Base: Total": "BOGMBASEW",
               "Base: Currency in Circulation": "MBCURRCIRW",
              "NGDP": "GDP",
              "Real GDP": "GDPC1"}

# Select start and end dates
# datetime.datetime(year, month, day)
start = datetime.datetime(1975, 1, 1)
end = datetime.datetime.today()

# %%
# freq refers to data frequency. Choose "D", "W", "M", "Q", "A"
#                               day, week, month, quarter, annual
# a number may also be place in front of a letter. "2D" indicates
#       alternating days
data = gather_data(data_codes = data_codes, 
                   start = start, 
                   end = end, 
                   freq = "Q")

# %%
data
# Out:
#              Base: Total  Base: Currency in Circulation        NGDP  \
# DATE
# 1975-03-31  1.062955e+05                   7.752108e+04   1616116.0
# 1975-06-30  1.072322e+05                   7.934238e+04   1651853.0
# 1975-09-30  1.092747e+05                   8.190892e+04   1709820.0
# 1975-12-31  1.111844e+05                   8.389500e+04   1761831.0
# 1976-03-31  1.112611e+05                   8.460008e+04   1820487.0
# ...                  ...                            ...         ...
# 2019-09-30  3.243848e+06                   1.752159e+06  21505012.0
# 2019-12-31  3.320522e+06                   1.782327e+06  21694458.0
# 2020-03-31  3.524601e+06                   1.806147e+06  21481367.0
# 2020-06-30  4.978059e+06                   1.921649e+06  19477444.0
# 2020-09-30  4.776974e+06                   1.995564e+06  21138574.0
#
#               Real GDP
# DATE
# 1975-03-31   5551713.0
# 1975-06-30   5591382.0
# 1975-09-30   5687087.0
# 1975-12-31   5763665.0
# 1976-03-31   5893276.0
# ...                ...
# 2019-09-30  19112653.0
# 2019-12-31  19202310.0
# 2020-03-31  18951992.0
# 2020-06-30  17258205.0
# 2020-09-30  18560774.0
#
# [183 rows x 4 columns]

# %% [markdown]
# We need to align the units of Nominal and Real GDP (Billions) with the units of the quantity of base money (Millions). We will multiply the GDP measure by 1000
#
# 1 Billion = 1000 Million

# %%
data["NGDP"] =  data["NGDP"].mul(1000)
data["Real GDP"] = data["Real GDP"].mul(1000)
data
# Out:
#              Base: Total  Base: Currency in Circulation        NGDP  \
# DATE
# 1975-03-31  1.062955e+05                   7.752108e+04   1616116.0
# 1975-06-30  1.072322e+05                   7.934238e+04   1651853.0
# 1975-09-30  1.092747e+05                   8.190892e+04   1709820.0
# 1975-12-31  1.111844e+05                   8.389500e+04   1761831.0
# 1976-03-31  1.112611e+05                   8.460008e+04   1820487.0
# ...                  ...                            ...         ...
# 2019-09-30  3.243848e+06                   1.752159e+06  21505012.0
# 2019-12-31  3.320522e+06                   1.782327e+06  21694458.0
# 2020-03-31  3.524601e+06                   1.806147e+06  21481367.0
# 2020-06-30  4.978059e+06                   1.921649e+06  19477444.0
# 2020-09-30  4.776974e+06                   1.995564e+06  21138574.0
#
#               Real GDP
# DATE
# 1975-03-31   5551713.0
# 1975-06-30   5591382.0
# 1975-09-30   5687087.0
# 1975-12-31   5763665.0
# 1976-03-31   5893276.0
# ...                ...
# 2019-09-30  19112653.0
# 2019-12-31  19202310.0
# 2020-03-31  18951992.0
# 2020-06-30  17258205.0
# 2020-09-30  18560774.0
#
# [183 rows x 4 columns]

# %% [markdown]
# Calculate GDP Deflator: The GDP Deflator is the  measure of the price level deduced from the calculation of real GDP.

# %%
Py = data["NGDP"]
y = data["Real GDP"]

P = Py / y
#P.plot(figsize = (20,10))
P
# Out:
# DATE
# 1975-03-31    0.291102
# 1975-06-30    0.295428
# 1975-09-30    0.300650
# 1975-12-31    0.305679
# 1976-03-31    0.308909
#                 ...
# 2019-09-30    1.125171
# 2019-12-31    1.129784
# 2020-03-31    1.133462
# 2020-06-30    1.128590
# 2020-09-30    1.138884
# Freq: Q-DEC, Length: 183, dtype: float64

# %%
Py = data["NGDP"]
y = data["Real GDP"]

data["GDP Deflator"] = Py / y
data.loc["2012"]
# Out:
#              Base: Total  Base: Currency in Circulation        NGDP  \
# DATE
# 2012-03-31  2.662997e+06                   1.081682e+06  16068824.0
# 2012-06-30  2.625365e+06                   1.103922e+06  16207130.0
# 2012-09-30  2.634274e+06                   1.118604e+06  16319540.0
# 2012-12-31  2.638775e+06                   1.145695e+06  16420386.0
#
#               Real GDP  GDP Deflator
# DATE
# 2012-03-31  16179968.0      0.993131
# 2012-06-30  16253726.0      0.997133
# 2012-09-30  16282151.0      1.002296
# 2012-12-31  16300035.0      1.007383

# %% [markdown]
# Next, calculate the velocity of money.
#
# V = Py / M

# %%
Py = data["NGDP"]
# Which measure of M??
M = data["Base: Total"]

V_base = Py / M
V_base
# Out:
# DATE
# 1975-03-31    15.203993
# 1975-06-30    15.404456
# 1975-09-30    15.646990
# 1975-12-31    15.846023
# 1976-03-31    16.362299
#                 ...
# 2019-09-30     6.629476
# 2019-12-31     6.533447
# 2020-03-31     6.094694
# 2020-06-30     3.912659
# 2020-09-30     4.425097
# Freq: Q-DEC, Length: 183, dtype: float64

# %%
Py = data["NGDP"]
# Which measure of M??
M = data["Base: Total"]

data["Base Velocity"] = Py / M
data
# Out:
#              Base: Total  Base: Currency in Circulation        NGDP  \
# DATE
# 1975-03-31  1.062955e+05                   7.752108e+04   1616116.0
# 1975-06-30  1.072322e+05                   7.934238e+04   1651853.0
# 1975-09-30  1.092747e+05                   8.190892e+04   1709820.0
# 1975-12-31  1.111844e+05                   8.389500e+04   1761831.0
# 1976-03-31  1.112611e+05                   8.460008e+04   1820487.0
# ...                  ...                            ...         ...
# 2019-09-30  3.243848e+06                   1.752159e+06  21505012.0
# 2019-12-31  3.320522e+06                   1.782327e+06  21694458.0
# 2020-03-31  3.524601e+06                   1.806147e+06  21481367.0
# 2020-06-30  4.978059e+06                   1.921649e+06  19477444.0
# 2020-09-30  4.776974e+06                   1.995564e+06  21138574.0
#
#               Real GDP  GDP Deflator  Base Velocity
# DATE
# 1975-03-31   5551713.0      0.291102      15.203993
# 1975-06-30   5591382.0      0.295428      15.404456
# 1975-09-30   5687087.0      0.300650      15.646990
# 1975-12-31   5763665.0      0.305679      15.846023
# 1976-03-31   5893276.0      0.308909      16.362299
# ...                ...           ...            ...
# 2019-09-30  19112653.0      1.125171       6.629476
# 2019-12-31  19202310.0      1.129784       6.533447
# 2020-03-31  18951992.0      1.133462       6.094694
# 2020-06-30  17258205.0      1.128590       3.912659
# 2020-09-30  18560774.0      1.138884       4.425097
#
# [183 rows x 6 columns]

# %%
Py = data["NGDP"]
# Which measure of M??
M = data["Base: Currency in Circulation"]

data["Currency Velocity"] = Py / M
data
# Out:
#              Base: Total  Base: Currency in Circulation        NGDP  \
# DATE
# 1975-03-31  1.062955e+05                   7.752108e+04   1616116.0
# 1975-06-30  1.072322e+05                   7.934238e+04   1651853.0
# 1975-09-30  1.092747e+05                   8.190892e+04   1709820.0
# 1975-12-31  1.111844e+05                   8.389500e+04   1761831.0
# 1976-03-31  1.112611e+05                   8.460008e+04   1820487.0
# ...                  ...                            ...         ...
# 2019-09-30  3.243848e+06                   1.752159e+06  21505012.0
# 2019-12-31  3.320522e+06                   1.782327e+06  21694458.0
# 2020-03-31  3.524601e+06                   1.806147e+06  21481367.0
# 2020-06-30  4.978059e+06                   1.921649e+06  19477444.0
# 2020-09-30  4.776974e+06                   1.995564e+06  21138574.0
#
#               Real GDP  GDP Deflator  Base Velocity  Currency Velocity
# DATE
# 1975-03-31   5551713.0      0.291102      15.203993          20.847438
# 1975-06-30   5591382.0      0.295428      15.404456          20.819301
# 1975-09-30   5687087.0      0.300650      15.646990          20.874649
# 1975-12-31   5763665.0      0.305679      15.846023          21.000429
# 1976-03-31   5893276.0      0.308909      16.362299          21.518739
# ...                ...           ...            ...                ...
# 2019-09-30  19112653.0      1.125171       6.629476          12.273435
# 2019-12-31  19202310.0      1.129784       6.533447          12.171982
# 2020-03-31  18951992.0      1.133462       6.094694          11.893480
# 2020-06-30  17258205.0      1.128590       3.912659          10.135797
# 2020-09-30  18560774.0      1.138884       4.425097          10.592783
#
# [183 rows x 7 columns]

# %% [markdown]
# How do we calculate inflation???

# %%
# use periods per year = 4 if quarterly data
periods_per_year = 4
data["Inflation"] = data["GDP Deflator"].pct_change(periods_per_year)
data["1980":"1981"]
# Out:
#               Base: Total  Base: Currency in Circulation       NGDP  \
# DATE
# 1980-03-31  155149.769231                  122653.846154  2789842.0
# 1980-06-30  158017.076923                  124890.076923  2797352.0
# 1980-09-30  159247.615385                  129073.000000  2856483.0
# 1980-12-31  161970.000000                  133108.142857  2985557.0
# 1981-03-31  159907.833333                  133057.333333  3124206.0
# 1981-06-30  162911.153846                  135905.692308  3162532.0
# 1981-09-30  165572.928571                  138939.285714  3260609.0
# 1981-12-31  167576.153846                  141575.769231  3280818.0
#
#              Real GDP  GDP Deflator  Base Velocity  Currency Velocity  \
# DATE
# 1980-03-31  6842024.0      0.407751      17.981606          22.745654
# 1980-06-30  6701046.0      0.417450      17.702846          22.398513
# 1980-09-30  6693082.0      0.426781      17.937367          22.130755
# 1980-12-31  6817903.0      0.437900      18.432778          22.429559
# 1981-03-31  6951495.0      0.449429      19.537542          23.480149
# 1981-06-30  6899980.0      0.458339      19.412618          23.270048
# 1981-09-30  6982609.0      0.466961      19.692887          23.467869
# 1981-12-31  6906529.0      0.475031      19.578072          23.173584
#
#             Inflation
# DATE
# 1980-03-31   0.088716
# 1980-06-30   0.087971
# 1980-09-30   0.088495
# 1980-12-31   0.096496
# 1981-03-31   0.102215
# 1981-06-30   0.097950
# 1981-09-30   0.094147
# 1981-12-31   0.084795

# %%
from datlib.plots import *
# set default fontsize
plt.rcParams.update({"font.size":40})
# choose variables to plot
plot_vars = ["NGDP", "Real GDP"]
plot_lines(data[plot_vars], linewidth = 5)
# Out:
# C:\Users\JLCat\GithubRepositories\Macroeconomics-Growth-and-Monetary-Equilibrium\Data Homework Assignments\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(x,2) for x in vals])

# %%
from datlib.plots import *
# set default fontsize
plt.rcParams.update({"font.size":40})
# choose variables to plot
plot_vars = ["Inflation"]
plot_lines(data[plot_vars], linewidth = 5)
# Out:
# C:\Users\JLCat\GithubRepositories\Macroeconomics-Growth-and-Monetary-Equilibrium\Data Homework Assignments\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([round(x,2) for x in vals])
