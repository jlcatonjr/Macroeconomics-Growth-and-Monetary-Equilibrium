# %% [markdown]
# # Data Homework Template
#
# ### This is a guide to help you complete the data homework assignments.
#
# We will import functions from the datlib folder. these will be used to import data and plot the data. You only need to understand how to enter input for these functions.
#
# To import data, we will need to specify the codes for the data and the range of dates for which we will collect data.

# %%
#plots.py
# if you have not installed pandas-datareader, uncomment the command 
# in the next line. After intallation, you can remove the command
#!pip install pandas-datareader
# pandas_datareader is imported in datlib.FRED
import datetime
from datlib.FRED import *
#Import monetary base
data_codes  = {"Base: Total": "BOGMBASEW",
               "Base: Currency in Circulation": "MBCURRCIRW",
               "Excess Reserves": "EXCSRESNW"}
# Select start and end dates
start = datetime.datetime(1975, 1, 1)
end = datetime.datetime.today()

# %%
# freq refers to data frequency. Choose "D", "W", "M", "Q", "A"
#                                       day, week, month, quarter, annual
# a number may also be place in front of a letter. "2D" indicates
#       alternating days
data = gather_data(data_codes = data_codes, start = start, end = end, freq = "M")

# %% [markdown]
# You can view the data by calling the entire dataframe.

# %%
data
# Out:
#             Base: Total  Base: Currency in Circulation  Excess Reserves
# DATE
# 1975-01-31    107789.25                       77860.50              NaN
# 1975-02-28    105592.00                       77009.50              NaN
# 1975-03-31    105505.25                       77693.25              NaN
# 1975-04-30    106762.00                       78466.60              NaN
# 1975-05-31    106920.75                       79176.50              NaN
# 1975-06-30    108131.25                       80603.00              NaN
# 1975-07-31    109537.80                       81756.00              NaN
# 1975-08-31    109065.25                       81911.25              NaN
# 1975-09-30    109155.25                       82097.75              NaN
# 1975-10-31    109605.80                       82204.00              NaN
# 1975-11-30    110874.75                       83648.00              NaN
# 1975-12-31    113010.80                       85783.60              NaN
# 1976-01-31    112082.25                       84889.25              NaN
# 1976-02-29    110543.50                       83992.00              NaN
# 1976-03-31    111178.20                       84855.20              NaN
# 1976-04-30    113022.00                       86518.75              NaN
# 1976-05-31    113560.75                       87218.75              NaN
# 1976-06-30    114324.60                       88357.60              NaN
# 1976-07-31    115576.00                       89357.25              NaN
# 1976-08-31    115607.50                       89490.75              NaN
# 1976-09-30    115502.80                       89688.80              NaN
# 1976-10-31    116476.25                       90198.75              NaN
# 1976-11-30    117918.50                       91459.50              NaN
# 1976-12-31    120123.00                       93463.40              NaN
# 1977-01-31    120140.00                       92862.25              NaN
# 1977-02-28    117830.25                       91623.25              NaN
# 1977-03-31    118546.20                       92603.60              NaN
# 1977-04-30    120546.50                       94215.50              NaN
# 1977-05-31    120955.00                       94754.00              NaN
# 1977-06-30    121633.20                       95832.80              NaN
# ...                 ...                            ...              ...
# 2018-04-30   3741948.50                     1639951.00       1976985.50
# 2018-05-31   3671684.80                     1651048.80       1892046.00
# 2018-06-30   3657684.50                     1661859.75       1870897.75
# 2018-07-31   3617603.00                     1668364.50       1824435.00
# 2018-08-31   3588211.20                     1671521.80       1791310.20
# 2018-09-30   3567610.50                     1685515.00       1755852.00
# 2018-10-31   3521056.40                     1690661.60       1706135.20
# 2018-11-30   3478664.00                     1700738.00       1651829.00
# 2018-12-31   3411575.75                     1707921.50       1580691.50
# 2019-01-31   3348160.20                     1709064.80       1507524.00
# 2019-02-28   3350748.50                     1707784.50       1518295.00
# 2019-03-31   3388656.50                     1719262.50       1540933.50
# 2019-04-30   3312633.50                     1726409.00       1457280.00
# 2019-05-31   3235396.80                     1732333.20       1368538.40
# 2019-06-30   3282619.00                     1738510.50       1410368.25
# 2019-07-31   3255978.40                     1746192.00       1373614.20
# 2019-08-31   3275209.00                     1749115.50       1391354.50
# 2019-09-30   3197323.50                     1762662.00       1300206.50
# 2019-10-31   3251883.40                     1770106.00       1346916.00
# 2019-11-30   3311717.00                     1785498.00       1386355.25
# 2019-12-31   3415126.50                     1794433.75       1482130.25
# 2020-01-31   3440867.80                     1798307.40       1496750.40
# 2020-02-29   3446282.50                     1795990.00       1513219.50
# 2020-03-31   3707586.50                     1826102.00       1740628.00
# 2020-04-30   4783890.20                     1888701.80       2895189.20
# 2020-05-31   5139460.00                     1928941.25       3210518.75
# 2020-06-30   5059368.25                     1955540.75       3103827.75
# 2020-07-31   4725875.20                     1977793.40       2748082.00
# 2020-08-31   4790990.00                     2004558.50       2786432.00
# 2020-09-30   4876690.00                     2022000.00       2854690.00
#
# [549 rows x 3 columns]

# %% [markdown]
# Or you can call specific rows by the order in which they appear. For example, if I want to call rows 0 through 9, call _data.iloc[start:last + 1].

# %%
data.iloc[0:10]
# Out:
#             Base: Total  Base: Currency in Circulation  Excess Reserves
# DATE
# 1975-01-31    107789.25                       77860.50              NaN
# 1975-02-28    105592.00                       77009.50              NaN
# 1975-03-31    105505.25                       77693.25              NaN
# 1975-04-30    106762.00                       78466.60              NaN
# 1975-05-31    106920.75                       79176.50              NaN
# 1975-06-30    108131.25                       80603.00              NaN
# 1975-07-31    109537.80                       81756.00              NaN
# 1975-08-31    109065.25                       81911.25              NaN
# 1975-09-30    109155.25                       82097.75              NaN
# 1975-10-31    109605.80                       82204.00              NaN

# %% [markdown]
# If you want to call dates from a certain year, call data.loc[year]. Make sure that the year is in quotations.

# %%
data.loc["1975"]
# Out:
#             Base: Total  Base: Currency in Circulation  Excess Reserves
# DATE
# 1975-01-31    107789.25                       77860.50              NaN
# 1975-02-28    105592.00                       77009.50              NaN
# 1975-03-31    105505.25                       77693.25              NaN
# 1975-04-30    106762.00                       78466.60              NaN
# 1975-05-31    106920.75                       79176.50              NaN
# 1975-06-30    108131.25                       80603.00              NaN
# 1975-07-31    109537.80                       81756.00              NaN
# 1975-08-31    109065.25                       81911.25              NaN
# 1975-09-30    109155.25                       82097.75              NaN
# 1975-10-31    109605.80                       82204.00              NaN
# 1975-11-30    110874.75                       83648.00              NaN
# 1975-12-31    113010.80                       85783.60              NaN

# %% [markdown]
# You can call a range of years using _data.loc[start:finish]_.

# %%
data.loc["2007":"2008"]
# Out:
#             Base: Total  Base: Currency in Circulation  Excess Reserves
# DATE
# 2007-01-31    824327.60                      808550.40          1620.20
# 2007-02-28    820044.50                      805364.00          1452.50
# 2007-03-31    820774.00                      806340.50          1589.00
# 2007-04-30    822611.00                      807557.00          1618.00
# 2007-05-31    825430.80                      809433.00          1469.20
# 2007-06-30    827169.50                      811798.00          1716.50
# 2007-07-31    828942.50                      814004.50          1675.00
# 2007-08-31    829483.60                      811740.60          4483.20
# 2007-09-30    827006.50                      811899.00          1658.00
# 2007-10-31    829213.80                      813927.60          1529.80
# 2007-11-30    834188.75                      819033.00          1684.00
# 2007-12-31    835965.25                      821229.00          1687.00
# 2008-01-31    832597.80                      817008.80          1753.40
# 2008-02-29    829288.00                      814429.00          1625.50
# 2008-03-31    833083.00                      816645.00          2719.50
# 2008-04-30    830476.20                      814126.40          1736.20
# 2008-05-31    834014.50                      817469.25          1802.50
# 2008-06-30    839757.75                      823283.25          2076.00
# 2008-07-31    846419.60                      829566.80          2071.00
# 2008-08-31    847064.50                      830514.00          1822.50
# 2008-09-30    883857.00                      833942.50         35067.00
# 2008-10-31   1105505.40                      849458.80        239078.80
# 2008-11-30   1422550.25                      864343.00        540411.75
# 2008-12-31   1645092.80                      877332.80        747010.60

# %% [markdown]
# # Selecting columns
#
# Instead of calling an entire dataframe, you can call a single column by passing a string (i,e., use quotation) the column name surrounded by brackets.

# %%
data["Base: Total"]
# Out:
# DATE
# 1975-01-31     107789.25
# 1975-02-28     105592.00
# 1975-03-31     105505.25
# 1975-04-30     106762.00
# 1975-05-31     106920.75
# 1975-06-30     108131.25
# 1975-07-31     109537.80
# 1975-08-31     109065.25
# 1975-09-30     109155.25
# 1975-10-31     109605.80
# 1975-11-30     110874.75
# 1975-12-31     113010.80
# 1976-01-31     112082.25
# 1976-02-29     110543.50
# 1976-03-31     111178.20
# 1976-04-30     113022.00
# 1976-05-31     113560.75
# 1976-06-30     114324.60
# 1976-07-31     115576.00
# 1976-08-31     115607.50
# 1976-09-30     115502.80
# 1976-10-31     116476.25
# 1976-11-30     117918.50
# 1976-12-31     120123.00
# 1977-01-31     120140.00
# 1977-02-28     117830.25
# 1977-03-31     118546.20
# 1977-04-30     120546.50
# 1977-05-31     120955.00
# 1977-06-30     121633.20
#                  ...
# 2018-04-30    3741948.50
# 2018-05-31    3671684.80
# 2018-06-30    3657684.50
# 2018-07-31    3617603.00
# 2018-08-31    3588211.20
# 2018-09-30    3567610.50
# 2018-10-31    3521056.40
# 2018-11-30    3478664.00
# 2018-12-31    3411575.75
# 2019-01-31    3348160.20
# 2019-02-28    3350748.50
# 2019-03-31    3388656.50
# 2019-04-30    3312633.50
# 2019-05-31    3235396.80
# 2019-06-30    3282619.00
# 2019-07-31    3255978.40
# 2019-08-31    3275209.00
# 2019-09-30    3197323.50
# 2019-10-31    3251883.40
# 2019-11-30    3311717.00
# 2019-12-31    3415126.50
# 2020-01-31    3440867.80
# 2020-02-29    3446282.50
# 2020-03-31    3707586.50
# 2020-04-30    4783890.20
# 2020-05-31    5139460.00
# 2020-06-30    5059368.25
# 2020-07-31    4725875.20
# 2020-08-31    4790990.00
# 2020-09-30    4876690.00
# Freq: M, Name: Base: Total, Length: 549, dtype: float64

# %% [markdown]
# You can also call multiple columns by passing a list of column names.

# %%
data[["Base: Total", "Base: Currency in Circulation"]]
# Out:
#             Base: Total  Base: Currency in Circulation
# DATE
# 1975-01-31    107789.25                       77860.50
# 1975-02-28    105592.00                       77009.50
# 1975-03-31    105505.25                       77693.25
# 1975-04-30    106762.00                       78466.60
# 1975-05-31    106920.75                       79176.50
# 1975-06-30    108131.25                       80603.00
# 1975-07-31    109537.80                       81756.00
# 1975-08-31    109065.25                       81911.25
# 1975-09-30    109155.25                       82097.75
# 1975-10-31    109605.80                       82204.00
# 1975-11-30    110874.75                       83648.00
# 1975-12-31    113010.80                       85783.60
# 1976-01-31    112082.25                       84889.25
# 1976-02-29    110543.50                       83992.00
# 1976-03-31    111178.20                       84855.20
# 1976-04-30    113022.00                       86518.75
# 1976-05-31    113560.75                       87218.75
# 1976-06-30    114324.60                       88357.60
# 1976-07-31    115576.00                       89357.25
# 1976-08-31    115607.50                       89490.75
# 1976-09-30    115502.80                       89688.80
# 1976-10-31    116476.25                       90198.75
# 1976-11-30    117918.50                       91459.50
# 1976-12-31    120123.00                       93463.40
# 1977-01-31    120140.00                       92862.25
# 1977-02-28    117830.25                       91623.25
# 1977-03-31    118546.20                       92603.60
# 1977-04-30    120546.50                       94215.50
# 1977-05-31    120955.00                       94754.00
# 1977-06-30    121633.20                       95832.80
# ...                 ...                            ...
# 2018-04-30   3741948.50                     1639951.00
# 2018-05-31   3671684.80                     1651048.80
# 2018-06-30   3657684.50                     1661859.75
# 2018-07-31   3617603.00                     1668364.50
# 2018-08-31   3588211.20                     1671521.80
# 2018-09-30   3567610.50                     1685515.00
# 2018-10-31   3521056.40                     1690661.60
# 2018-11-30   3478664.00                     1700738.00
# 2018-12-31   3411575.75                     1707921.50
# 2019-01-31   3348160.20                     1709064.80
# 2019-02-28   3350748.50                     1707784.50
# 2019-03-31   3388656.50                     1719262.50
# 2019-04-30   3312633.50                     1726409.00
# 2019-05-31   3235396.80                     1732333.20
# 2019-06-30   3282619.00                     1738510.50
# 2019-07-31   3255978.40                     1746192.00
# 2019-08-31   3275209.00                     1749115.50
# 2019-09-30   3197323.50                     1762662.00
# 2019-10-31   3251883.40                     1770106.00
# 2019-11-30   3311717.00                     1785498.00
# 2019-12-31   3415126.50                     1794433.75
# 2020-01-31   3440867.80                     1798307.40
# 2020-02-29   3446282.50                     1795990.00
# 2020-03-31   3707586.50                     1826102.00
# 2020-04-30   4783890.20                     1888701.80
# 2020-05-31   5139460.00                     1928941.25
# 2020-06-30   5059368.25                     1955540.75
# 2020-07-31   4725875.20                     1977793.40
# 2020-08-31   4790990.00                     2004558.50
# 2020-09-30   4876690.00                     2022000.00
#
# [549 rows x 2 columns]

# %% [markdown]
# Finally, you can define the list before passing it. This will make it easier to call the same column names again later.

# %%
names = ["Base: Total", "Base: Currency in Circulation"]
data[names]
# Out:
#             Base: Total  Base: Currency in Circulation
# DATE
# 1975-01-31    107789.25                       77860.50
# 1975-02-28    105592.00                       77009.50
# 1975-03-31    105505.25                       77693.25
# 1975-04-30    106762.00                       78466.60
# 1975-05-31    106920.75                       79176.50
# 1975-06-30    108131.25                       80603.00
# 1975-07-31    109537.80                       81756.00
# 1975-08-31    109065.25                       81911.25
# 1975-09-30    109155.25                       82097.75
# 1975-10-31    109605.80                       82204.00
# 1975-11-30    110874.75                       83648.00
# 1975-12-31    113010.80                       85783.60
# 1976-01-31    112082.25                       84889.25
# 1976-02-29    110543.50                       83992.00
# 1976-03-31    111178.20                       84855.20
# 1976-04-30    113022.00                       86518.75
# 1976-05-31    113560.75                       87218.75
# 1976-06-30    114324.60                       88357.60
# 1976-07-31    115576.00                       89357.25
# 1976-08-31    115607.50                       89490.75
# 1976-09-30    115502.80                       89688.80
# 1976-10-31    116476.25                       90198.75
# 1976-11-30    117918.50                       91459.50
# 1976-12-31    120123.00                       93463.40
# 1977-01-31    120140.00                       92862.25
# 1977-02-28    117830.25                       91623.25
# 1977-03-31    118546.20                       92603.60
# 1977-04-30    120546.50                       94215.50
# 1977-05-31    120955.00                       94754.00
# 1977-06-30    121633.20                       95832.80
# ...                 ...                            ...
# 2018-04-30   3741948.50                     1639951.00
# 2018-05-31   3671684.80                     1651048.80
# 2018-06-30   3657684.50                     1661859.75
# 2018-07-31   3617603.00                     1668364.50
# 2018-08-31   3588211.20                     1671521.80
# 2018-09-30   3567610.50                     1685515.00
# 2018-10-31   3521056.40                     1690661.60
# 2018-11-30   3478664.00                     1700738.00
# 2018-12-31   3411575.75                     1707921.50
# 2019-01-31   3348160.20                     1709064.80
# 2019-02-28   3350748.50                     1707784.50
# 2019-03-31   3388656.50                     1719262.50
# 2019-04-30   3312633.50                     1726409.00
# 2019-05-31   3235396.80                     1732333.20
# 2019-06-30   3282619.00                     1738510.50
# 2019-07-31   3255978.40                     1746192.00
# 2019-08-31   3275209.00                     1749115.50
# 2019-09-30   3197323.50                     1762662.00
# 2019-10-31   3251883.40                     1770106.00
# 2019-11-30   3311717.00                     1785498.00
# 2019-12-31   3415126.50                     1794433.75
# 2020-01-31   3440867.80                     1798307.40
# 2020-02-29   3446282.50                     1795990.00
# 2020-03-31   3707586.50                     1826102.00
# 2020-04-30   4783890.20                     1888701.80
# 2020-05-31   5139460.00                     1928941.25
# 2020-06-30   5059368.25                     1955540.75
# 2020-07-31   4725875.20                     1977793.40
# 2020-08-31   4790990.00                     2004558.50
# 2020-09-30   4876690.00                     2022000.00
#
# [549 rows x 2 columns]

# %% [markdown]
# # Plotting data
#
# ### Line Plots
#
# Now that the data has been imported, we can visualize it using plot_lines(), which we import from datlib.plots

# %%
from datlib.plots import * 
# set default fontsize
plt.rcParams.update({"font.size":32})
plot_lines(df = data, linewidth = 1, figsize = (40, 20))
# Out:
# C:\Users\JLCat\GithubRepositories\Macroeconomics-Growth-and-Monetary-Equilibrium\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([int(x) for x in vals])

# %% [markdown]
# You might only want to plot one column of data. In that case, just pass the dataframe that calls that one column.

# %%
data_to_plot = data["Base: Total"]
plot_lines(df = data_to_plot, linewidth = 1, figsize = (40, 20))
# Out:
# C:\Users\JLCat\GithubRepositories\Macroeconomics-Growth-and-Monetary-Equilibrium\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([int(x) for x in vals])

# %% [markdown]
# The plot_lines() function also includes an option for a secondary y-axis.

# %%
plot_lines(df = data, linewidth = 1, figsize = (40, 20), secondary_y = "Base: Total")
# Out:
# C:\Users\JLCat\GithubRepositories\Macroeconomics-Growth-and-Monetary-Equilibrium\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([int(x) for x in vals])

# %% [markdown]
# ### Stacked Plots
#
# Suppose that you want to see how the values of different components of an aggregate change over time. For example, the total base is composed of currency in circulation and reserves. Let's see how much of the base is comprised of these values. The remaining value, required reserves, is implied by the gap between the dotted line and the stacked plots.
#
# Unlike in our line function, the *plot_stacked_vars()* function does not simply plot every value in the dataframe. Instead, we must define which values will be stacked and which variable represents the value of the entire aggregate.

# %%
stack_vars = ["Base: Currency in Circulation",
             "Excess Reserves"]
aggregate_var = "Base: Total"
plot_stacked_lines(data, stack_vars, linewidth = 1, 
                       figsize = (40, 20),
                    total_var = aggregate_var,
                      title = "Components of the Monetary Base")

# %% [markdown]
# ### Scatter Plots
#
# You may also create scatter plots by selecting two or more variables. The _plot_scatter()_ tracks time by using color.

# %%
plot_scatter(data=data, s = 75, figsize = (40, 20), save_fig = False, pp = None)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %% [markdown]
# ### Creating New Columns
#
# Suppose that you want to create a new variable: the fraction of the monetary base that is currency in circulation. To do so with _pandas_ is quite simple. You can accomplish this in one of two ways.
#
# You can use the _.div()_ method from pandas: data[var1].div(data[var2])

# %%
data["Excess Reserves / Base"] = data["Excess Reserves"].div(data["Base: Total"])

# %% [markdown]
# Alternately, you can just use the math operators instead of *.div()* or any of the other dataframe methods (i.e., *.add()*, *.sub()*, *.mul()*, *.pow()*)

# %%
data["Excess Reserves / Base"] = data["Excess Reserves"] / data["Base: Total"]
data["Excess Reserves / Base"]
# Out:
# DATE
# 1975-01-31         NaN
# 1975-02-28         NaN
# 1975-03-31         NaN
# 1975-04-30         NaN
# 1975-05-31         NaN
# 1975-06-30         NaN
# 1975-07-31         NaN
# 1975-08-31         NaN
# 1975-09-30         NaN
# 1975-10-31         NaN
# 1975-11-30         NaN
# 1975-12-31         NaN
# 1976-01-31         NaN
# 1976-02-29         NaN
# 1976-03-31         NaN
# 1976-04-30         NaN
# 1976-05-31         NaN
# 1976-06-30         NaN
# 1976-07-31         NaN
# 1976-08-31         NaN
# 1976-09-30         NaN
# 1976-10-31         NaN
# 1976-11-30         NaN
# 1976-12-31         NaN
# 1977-01-31         NaN
# 1977-02-28         NaN
# 1977-03-31         NaN
# 1977-04-30         NaN
# 1977-05-31         NaN
# 1977-06-30         NaN
#                 ...
# 2018-04-30    0.528330
# 2018-05-31    0.515307
# 2018-06-30    0.511498
# 2018-07-31    0.504322
# 2018-08-31    0.499221
# 2018-09-30    0.492165
# 2018-10-31    0.484552
# 2018-11-30    0.474846
# 2018-12-31    0.463332
# 2019-01-31    0.450254
# 2019-02-28    0.453121
# 2019-03-31    0.454733
# 2019-04-30    0.439916
# 2019-05-31    0.422989
# 2019-06-30    0.429647
# 2019-07-31    0.421874
# 2019-08-31    0.424814
# 2019-09-30    0.406655
# 2019-10-31    0.414196
# 2019-11-30    0.418621
# 2019-12-31    0.433990
# 2020-01-31    0.434992
# 2020-02-29    0.439087
# 2020-03-31    0.469477
# 2020-04-30    0.605196
# 2020-05-31    0.624680
# 2020-06-30    0.613481
# 2020-07-31    0.581497
# 2020-08-31    0.581598
# 2020-09-30    0.585375
# Freq: M, Name: Excess Reserves / Base, Length: 549, dtype: float64

# %%
plot_lines(df = data, linewidth = 1, figsize = (40, 20), secondary_y = "Excess Reserves / Base")
# Out:
# C:\Users\JLCat\GithubRepositories\Macroeconomics-Growth-and-Monetary-Equilibrium\datlib\plots.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels([int(x) for x in vals])
